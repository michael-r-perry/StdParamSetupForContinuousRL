# %%
import gymnasium as gym

env = gym.make("Hopper-v4", render_mode="human")

observation, info = env.reset(seed=42)
for _ in range(1000):
    action = env.action_space.sample()
    observation, reward, terminated, truncated, info = env.step(action)
    env.render()
    if terminated or truncated:
        observation, info = env.reset()
env.close()

# %%
env.action_space.shape[0]
# Out:
# 3

# %%
print(env.observation_space)
print(env.observation_space.shape)
print("Lows:", env.observation_space.low, "High:", env.observation_space.high)
print(type(env.observation_space.low))
# Out:
# Box(-inf, inf, (11,), float64)
# (11,)
# Lows: [-inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf] High: [inf inf inf inf inf inf inf inf inf inf inf]
# <class 'numpy.ndarray'>

# %%
list(zip(env.observation_space.low, env.observation_space.high))
# Out:
# [(-inf, inf),
#  (-inf, inf),
#  (-inf, inf),
#  (-inf, inf),
#  (-inf, inf),
#  (-inf, inf),
#  (-inf, inf),
#  (-inf, inf),
#  (-inf, inf),
#  (-inf, inf),
#  (-inf, inf)]

# %%
import torch as th
from torch import nn

class ParamModule(nn.Module):
    def __init__(self):
        super().__init__()
        self.param = nn.Parameter(th.rand(2))
    def forward(self, x: th.Tensor) -> th.Tensor:
        return self.param[0] * x + self.param[1]

# %%
params = ParamModule()
x = th.Tensor([2, 2])
print("x:", x)
print("params:", params.param)
print("params(x):", params(x))
print(params.parameters())
# Out:
# x: tensor([2., 2.])
# params: Parameter containing:
# tensor([0.9994, 0.7086], requires_grad=True)
# params(x): tensor([2.7074, 2.7074], grad_fn=<AddBackward0>)
# <generator object Module.parameters at 0x0000016C58746EB0>

# %%
model = ParamModule()
lr = 0.1
loss_fn = nn.MSELoss()
opt = th.optim.Adam(model.parameters(), lr=lr)

X = th.range(1, 10)
Y = 2 * X + 15

for epoch in range(10000):
    pred = model(X)
    loss = loss_fn(pred, Y)

    opt.zero_grad()
    loss.backward()
    opt.step()

    print(f"Epoch {epoch}:", model.param)
# Out:
# C:\Users\Michael\AppData\Local\Temp\ipykernel_42624\2964524034.py:6: UserWarning: torch.range is deprecated and will be removed in a future release because its behavior is inconsistent with Python's range builtin. Instead, use torch.arange, which produces values in [start, end).
#   X = th.range(1, 10)
# Epoch 0: Parameter containing:
# tensor([0.1872, 0.1447], requires_grad=True)
# Epoch 1: Parameter containing:
# tensor([0.2871, 0.2446], requires_grad=True)
# Epoch 2: Parameter containing:
# tensor([0.3868, 0.3444], requires_grad=True)
# Epoch 3: Parameter containing:
# tensor([0.4864, 0.4440], requires_grad=True)
# Epoch 4: Parameter containing:
# tensor([0.5857, 0.5434], requires_grad=True)
# Epoch 5: Parameter containing:
# tensor([0.6846, 0.6424], requires_grad=True)
# Epoch 6: Parameter containing:
# tensor([0.7832, 0.7412], requires_grad=True)
# Epoch 7: Parameter containing:
# tensor([0.8813, 0.8395], requires_grad=True)
# Epoch 8: Parameter containing:
# tensor([0.9788, 0.9373], requires_grad=True)
# Epoch 9: Parameter containing:
# tensor([1.0757, 1.0345], requires_grad=True)
# Epoch 10: Parameter containing:
# tensor([1.1718, 1.1312], requires_grad=True)
# Epoch 11: Parameter containing:
# tensor([1.2672, 1.2271], requires_grad=True)
# Epoch 12: Parameter containing:
# tensor([1.3618, 1.3224], requires_grad=True)
# Epoch 13: Parameter containing:
# tensor([1.4554, 1.4168], requires_grad=True)
# Epoch 14: Parameter containing:
# tensor([1.5479, 1.5103], requires_grad=True)
# Epoch 15: Parameter containing:
# tensor([1.6394, 1.6029], requires_grad=True)
# Epoch 16: Parameter containing:
# tensor([1.7297, 1.6944], requires_grad=True)
# Epoch 17: Parameter containing:
# tensor([1.8187, 1.7849], requires_grad=True)
# Epoch 18: Parameter containing:
# tensor([1.9063, 1.8743], requires_grad=True)
# Epoch 19: Parameter containing:
# tensor([1.9925, 1.9624], requires_grad=True)
# Epoch 20: Parameter containing:
# tensor([2.0772, 2.0492], requires_grad=True)
# Epoch 21: Parameter containing:
# tensor([2.1603, 2.1347], requires_grad=True)
# Epoch 22: Parameter containing:
# tensor([2.2418, 2.2189], requires_grad=True)
# Epoch 23: Parameter containing:
# tensor([2.3214, 2.3015], requires_grad=True)
# Epoch 24: Parameter containing:
# tensor([2.3993, 2.3826], requires_grad=True)
# Epoch 25: Parameter containing:
# tensor([2.4753, 2.4622], requires_grad=True)
# Epoch 26: Parameter containing:
# tensor([2.5493, 2.5401], requires_grad=True)
# Epoch 27: Parameter containing:
# tensor([2.6212, 2.6164], requires_grad=True)
# Epoch 28: Parameter containing:
# tensor([2.6911, 2.6909], requires_grad=True)
# Epoch 29: Parameter containing:
# tensor([2.7588, 2.7637], requires_grad=True)
# Epoch 30: Parameter containing:
# tensor([2.8243, 2.8347], requires_grad=True)
# Epoch 31: Parameter containing:
# tensor([2.8876, 2.9038], requires_grad=True)
# Epoch 32: Parameter containing:
# tensor([2.9486, 2.9711], requires_grad=True)
# Epoch 33: Parameter containing:
# tensor([3.0073, 3.0365], requires_grad=True)
# Epoch 34: Parameter containing:
# tensor([3.0636, 3.1000], requires_grad=True)
# Epoch 35: Parameter containing:
# tensor([3.1175, 3.1616], requires_grad=True)
# Epoch 36: Parameter containing:
# tensor([3.1690, 3.2213], requires_grad=True)
# Epoch 37: Parameter containing:
# tensor([3.2180, 3.2790], requires_grad=True)
# Epoch 38: Parameter containing:
# tensor([3.2647, 3.3347], requires_grad=True)
# Epoch 39: Parameter containing:
# tensor([3.3089, 3.3886], requires_grad=True)
# Epoch 40: Parameter containing:
# tensor([3.3507, 3.4405], requires_grad=True)
# Epoch 41: Parameter containing:
# tensor([3.3901, 3.4904], requires_grad=True)
# Epoch 42: Parameter containing:
# tensor([3.4270, 3.5385], requires_grad=True)
# Epoch 43: Parameter containing:
# tensor([3.4616, 3.5847], requires_grad=True)
# Epoch 44: Parameter containing:
# tensor([3.4939, 3.6291], requires_grad=True)
# Epoch 45: Parameter containing:
# tensor([3.5238, 3.6717], requires_grad=True)
# Epoch 46: Parameter containing:
# tensor([3.5515, 3.7124], requires_grad=True)
# Epoch 47: Parameter containing:
# tensor([3.5770, 3.7515], requires_grad=True)
# Epoch 48: Parameter containing:
# tensor([3.6002, 3.7888], requires_grad=True)
# Epoch 49: Parameter containing:
# tensor([3.6214, 3.8245], requires_grad=True)
# Epoch 50: Parameter containing:
# tensor([3.6405, 3.8586], requires_grad=True)
# Epoch 51: Parameter containing:
# tensor([3.6576, 3.8912], requires_grad=True)
# Epoch 52: Parameter containing:
# tensor([3.6728, 3.9222], requires_grad=True)
# Epoch 53: Parameter containing:
# tensor([3.6862, 3.9519], requires_grad=True)
# Epoch 54: Parameter containing:
# tensor([3.6977, 3.9802], requires_grad=True)
# Epoch 55: Parameter containing:
# tensor([3.7076, 4.0072], requires_grad=True)
# Epoch 56: Parameter containing:
# tensor([3.7158, 4.0329], requires_grad=True)
# Epoch 57: Parameter containing:
# tensor([3.7225, 4.0575], requires_grad=True)
# Epoch 58: Parameter containing:
# tensor([3.7278, 4.0810], requires_grad=True)
# Epoch 59: Parameter containing:
# tensor([3.7316, 4.1034], requires_grad=True)
# Epoch 60: Parameter containing:
# tensor([3.7341, 4.1249], requires_grad=True)
# Epoch 61: Parameter containing:
# tensor([3.7355, 4.1455], requires_grad=True)
# Epoch 62: Parameter containing:
# tensor([3.7356, 4.1652], requires_grad=True)
# Epoch 63: Parameter containing:
# tensor([3.7348, 4.1842], requires_grad=True)
# Epoch 64: Parameter containing:
# tensor([3.7329, 4.2025], requires_grad=True)
# Epoch 65: Parameter containing:
# tensor([3.7302, 4.2201], requires_grad=True)
# Epoch 66: Parameter containing:
# tensor([3.7266, 4.2372], requires_grad=True)
# Epoch 67: Parameter containing:
# tensor([3.7223, 4.2537], requires_grad=True)
# Epoch 68: Parameter containing:
# tensor([3.7173, 4.2698], requires_grad=True)
# Epoch 69: Parameter containing:
# tensor([3.7117, 4.2856], requires_grad=True)
# Epoch 70: Parameter containing:
# tensor([3.7056, 4.3009], requires_grad=True)
# Epoch 71: Parameter containing:
# tensor([3.6990, 4.3160], requires_grad=True)
# Epoch 72: Parameter containing:
# tensor([3.6920, 4.3309], requires_grad=True)
# Epoch 73: Parameter containing:
# tensor([3.6847, 4.3456], requires_grad=True)
# Epoch 74: Parameter containing:
# tensor([3.6770, 4.3602], requires_grad=True)
# Epoch 75: Parameter containing:
# tensor([3.6692, 4.3746], requires_grad=True)
# Epoch 76: Parameter containing:
# tensor([3.6611, 4.3891], requires_grad=True)
# Epoch 77: Parameter containing:
# tensor([3.6530, 4.4035], requires_grad=True)
# Epoch 78: Parameter containing:
# tensor([3.6447, 4.4179], requires_grad=True)
# Epoch 79: Parameter containing:
# tensor([3.6364, 4.4324], requires_grad=True)
# Epoch 80: Parameter containing:
# tensor([3.6281, 4.4471], requires_grad=True)
# Epoch 81: Parameter containing:
# tensor([3.6198, 4.4618], requires_grad=True)
# Epoch 82: Parameter containing:
# tensor([3.6115, 4.4767], requires_grad=True)
# Epoch 83: Parameter containing:
# tensor([3.6034, 4.4917], requires_grad=True)
# Epoch 84: Parameter containing:
# tensor([3.5954, 4.5069], requires_grad=True)
# Epoch 85: Parameter containing:
# tensor([3.5875, 4.5224], requires_grad=True)
# Epoch 86: Parameter containing:
# tensor([3.5798, 4.5381], requires_grad=True)
# Epoch 87: Parameter containing:
# tensor([3.5722, 4.5540], requires_grad=True)
# Epoch 88: Parameter containing:
# tensor([3.5648, 4.5701], requires_grad=True)
# Epoch 89: Parameter containing:
# tensor([3.5577, 4.5866], requires_grad=True)
# Epoch 90: Parameter containing:
# tensor([3.5507, 4.6033], requires_grad=True)
# Epoch 91: Parameter containing:
# tensor([3.5440, 4.6202], requires_grad=True)
# Epoch 92: Parameter containing:
# tensor([3.5375, 4.6375], requires_grad=True)
# Epoch 93: Parameter containing:
# tensor([3.5313, 4.6550], requires_grad=True)
# Epoch 94: Parameter containing:
# tensor([3.5252, 4.6728], requires_grad=True)
# Epoch 95: Parameter containing:
# tensor([3.5194, 4.6909], requires_grad=True)
# Epoch 96: Parameter containing:
# tensor([3.5139, 4.7092], requires_grad=True)
# Epoch 97: Parameter containing:
# tensor([3.5085, 4.7278], requires_grad=True)
# Epoch 98: Parameter containing:
# tensor([3.5034, 4.7467], requires_grad=True)
# Epoch 99: Parameter containing:
# tensor([3.4985, 4.7658], requires_grad=True)
# Epoch 100: Parameter containing:
# tensor([3.4938, 4.7852], requires_grad=True)
# Epoch 101: Parameter containing:
# tensor([3.4894, 4.8049], requires_grad=True)
# Epoch 102: Parameter containing:
# tensor([3.4851, 4.8247], requires_grad=True)
# Epoch 103: Parameter containing:
# tensor([3.4810, 4.8448], requires_grad=True)
# Epoch 104: Parameter containing:
# tensor([3.4770, 4.8651], requires_grad=True)
# Epoch 105: Parameter containing:
# tensor([3.4733, 4.8856], requires_grad=True)
# Epoch 106: Parameter containing:
# tensor([3.4697, 4.9063], requires_grad=True)
# Epoch 107: Parameter containing:
# tensor([3.4662, 4.9272], requires_grad=True)
# Epoch 108: Parameter containing:
# tensor([3.4629, 4.9483], requires_grad=True)
# Epoch 109: Parameter containing:
# tensor([3.4597, 4.9695], requires_grad=True)
# Epoch 110: Parameter containing:
# tensor([3.4566, 4.9909], requires_grad=True)
# Epoch 111: Parameter containing:
# tensor([3.4536, 5.0125], requires_grad=True)
# Epoch 112: Parameter containing:
# tensor([3.4507, 5.0341], requires_grad=True)
# Epoch 113: Parameter containing:
# tensor([3.4478, 5.0559], requires_grad=True)
# Epoch 114: Parameter containing:
# tensor([3.4451, 5.0778], requires_grad=True)
# Epoch 115: Parameter containing:
# tensor([3.4424, 5.0998], requires_grad=True)
# Epoch 116: Parameter containing:
# tensor([3.4397, 5.1219], requires_grad=True)
# Epoch 117: Parameter containing:
# tensor([3.4371, 5.1441], requires_grad=True)
# Epoch 118: Parameter containing:
# tensor([3.4345, 5.1664], requires_grad=True)
# Epoch 119: Parameter containing:
# tensor([3.4319, 5.1887], requires_grad=True)
# Epoch 120: Parameter containing:
# tensor([3.4293, 5.2111], requires_grad=True)
# Epoch 121: Parameter containing:
# tensor([3.4268, 5.2335], requires_grad=True)
# Epoch 122: Parameter containing:
# tensor([3.4242, 5.2560], requires_grad=True)
# Epoch 123: Parameter containing:
# tensor([3.4217, 5.2786], requires_grad=True)
# Epoch 124: Parameter containing:
# tensor([3.4191, 5.3012], requires_grad=True)
# Epoch 125: Parameter containing:
# tensor([3.4165, 5.3238], requires_grad=True)
# Epoch 126: Parameter containing:
# tensor([3.4139, 5.3464], requires_grad=True)
# Epoch 127: Parameter containing:
# tensor([3.4113, 5.3691], requires_grad=True)
# Epoch 128: Parameter containing:
# tensor([3.4086, 5.3918], requires_grad=True)
# Epoch 129: Parameter containing:
# tensor([3.4059, 5.4145], requires_grad=True)
# Epoch 130: Parameter containing:
# tensor([3.4032, 5.4372], requires_grad=True)
# Epoch 131: Parameter containing:
# tensor([3.4004, 5.4599], requires_grad=True)
# Epoch 132: Parameter containing:
# tensor([3.3976, 5.4826], requires_grad=True)
# Epoch 133: Parameter containing:
# tensor([3.3948, 5.5054], requires_grad=True)
# Epoch 134: Parameter containing:
# tensor([3.3919, 5.5281], requires_grad=True)
# Epoch 135: Parameter containing:
# tensor([3.3890, 5.5509], requires_grad=True)
# Epoch 136: Parameter containing:
# tensor([3.3860, 5.5736], requires_grad=True)
# Epoch 137: Parameter containing:
# tensor([3.3830, 5.5964], requires_grad=True)
# Epoch 138: Parameter containing:
# tensor([3.3800, 5.6191], requires_grad=True)
# Epoch 139: Parameter containing:
# tensor([3.3769, 5.6419], requires_grad=True)
# Epoch 140: Parameter containing:
# tensor([3.3738, 5.6646], requires_grad=True)
# Epoch 141: Parameter containing:
# tensor([3.3706, 5.6874], requires_grad=True)
# Epoch 142: Parameter containing:
# tensor([3.3675, 5.7102], requires_grad=True)
# Epoch 143: Parameter containing:
# tensor([3.3642, 5.7329], requires_grad=True)
# Epoch 144: Parameter containing:
# tensor([3.3610, 5.7557], requires_grad=True)
# Epoch 145: Parameter containing:
# tensor([3.3577, 5.7785], requires_grad=True)
# Epoch 146: Parameter containing:
# tensor([3.3544, 5.8013], requires_grad=True)
# Epoch 147: Parameter containing:
# tensor([3.3511, 5.8241], requires_grad=True)
# Epoch 148: Parameter containing:
# tensor([3.3477, 5.8469], requires_grad=True)
# Epoch 149: Parameter containing:
# tensor([3.3443, 5.8697], requires_grad=True)
# Epoch 150: Parameter containing:
# tensor([3.3409, 5.8925], requires_grad=True)
# Epoch 151: Parameter containing:
# tensor([3.3375, 5.9153], requires_grad=True)
# Epoch 152: Parameter containing:
# tensor([3.3341, 5.9382], requires_grad=True)
# Epoch 153: Parameter containing:
# tensor([3.3306, 5.9610], requires_grad=True)
# Epoch 154: Parameter containing:
# tensor([3.3272, 5.9839], requires_grad=True)
# Epoch 155: Parameter containing:
# tensor([3.3237, 6.0068], requires_grad=True)
# Epoch 156: Parameter containing:
# tensor([3.3202, 6.0297], requires_grad=True)
# Epoch 157: Parameter containing:
# tensor([3.3167, 6.0526], requires_grad=True)
# Epoch 158: Parameter containing:
# tensor([3.3133, 6.0755], requires_grad=True)
# Epoch 159: Parameter containing:
# tensor([3.3098, 6.0984], requires_grad=True)
# Epoch 160: Parameter containing:
# tensor([3.3063, 6.1214], requires_grad=True)
# Epoch 161: Parameter containing:
# tensor([3.3028, 6.1443], requires_grad=True)
# Epoch 162: Parameter containing:
# tensor([3.2993, 6.1673], requires_grad=True)
# Epoch 163: Parameter containing:
# tensor([3.2958, 6.1903], requires_grad=True)
# Epoch 164: Parameter containing:
# tensor([3.2923, 6.2133], requires_grad=True)
# Epoch 165: Parameter containing:
# tensor([3.2888, 6.2364], requires_grad=True)
# Epoch 166: Parameter containing:
# tensor([3.2853, 6.2594], requires_grad=True)
# Epoch 167: Parameter containing:
# tensor([3.2818, 6.2825], requires_grad=True)
# Epoch 168: Parameter containing:
# tensor([3.2783, 6.3056], requires_grad=True)
# Epoch 169: Parameter containing:
# tensor([3.2748, 6.3287], requires_grad=True)
# Epoch 170: Parameter containing:
# tensor([3.2713, 6.3518], requires_grad=True)
# Epoch 171: Parameter containing:
# tensor([3.2678, 6.3749], requires_grad=True)
# Epoch 172: Parameter containing:
# tensor([3.2644, 6.3981], requires_grad=True)
# Epoch 173: Parameter containing:
# tensor([3.2609, 6.4212], requires_grad=True)
# Epoch 174: Parameter containing:
# tensor([3.2574, 6.4444], requires_grad=True)
# Epoch 175: Parameter containing:
# tensor([3.2540, 6.4676], requires_grad=True)
# Epoch 176: Parameter containing:
# tensor([3.2505, 6.4908], requires_grad=True)
# Epoch 177: Parameter containing:
# tensor([3.2471, 6.5140], requires_grad=True)
# Epoch 178: Parameter containing:
# tensor([3.2436, 6.5372], requires_grad=True)
# Epoch 179: Parameter containing:
# tensor([3.2402, 6.5605], requires_grad=True)
# Epoch 180: Parameter containing:
# tensor([3.2368, 6.5837], requires_grad=True)
# Epoch 181: Parameter containing:
# tensor([3.2333, 6.6069], requires_grad=True)
# Epoch 182: Parameter containing:
# tensor([3.2299, 6.6302], requires_grad=True)
# Epoch 183: Parameter containing:
# tensor([3.2265, 6.6535], requires_grad=True)
# Epoch 184: Parameter containing:
# tensor([3.2231, 6.6767], requires_grad=True)
# Epoch 185: Parameter containing:
# tensor([3.2196, 6.7000], requires_grad=True)
# Epoch 186: Parameter containing:
# tensor([3.2162, 6.7233], requires_grad=True)
# Epoch 187: Parameter containing:
# tensor([3.2128, 6.7465], requires_grad=True)
# Epoch 188: Parameter containing:
# tensor([3.2094, 6.7698], requires_grad=True)
# Epoch 189: Parameter containing:
# tensor([3.2060, 6.7931], requires_grad=True)
# Epoch 190: Parameter containing:
# tensor([3.2026, 6.8164], requires_grad=True)
# Epoch 191: Parameter containing:
# tensor([3.1992, 6.8397], requires_grad=True)
# Epoch 192: Parameter containing:
# tensor([3.1958, 6.8630], requires_grad=True)
# Epoch 193: Parameter containing:
# tensor([3.1924, 6.8862], requires_grad=True)
# Epoch 194: Parameter containing:
# tensor([3.1890, 6.9095], requires_grad=True)
# Epoch 195: Parameter containing:
# tensor([3.1856, 6.9328], requires_grad=True)
# Epoch 196: Parameter containing:
# tensor([3.1822, 6.9561], requires_grad=True)
# Epoch 197: Parameter containing:
# tensor([3.1787, 6.9793], requires_grad=True)
# Epoch 198: Parameter containing:
# tensor([3.1753, 7.0026], requires_grad=True)
# Epoch 199: Parameter containing:
# tensor([3.1719, 7.0259], requires_grad=True)
# Epoch 200: Parameter containing:
# tensor([3.1685, 7.0491], requires_grad=True)
# Epoch 201: Parameter containing:
# tensor([3.1651, 7.0724], requires_grad=True)
# Epoch 202: Parameter containing:
# tensor([3.1617, 7.0956], requires_grad=True)
# Epoch 203: Parameter containing:
# tensor([3.1583, 7.1189], requires_grad=True)
# Epoch 204: Parameter containing:
# tensor([3.1549, 7.1421], requires_grad=True)
# Epoch 205: Parameter containing:
# tensor([3.1515, 7.1653], requires_grad=True)
# Epoch 206: Parameter containing:
# tensor([3.1481, 7.1885], requires_grad=True)
# Epoch 207: Parameter containing:
# tensor([3.1447, 7.2117], requires_grad=True)
# Epoch 208: Parameter containing:
# tensor([3.1413, 7.2349], requires_grad=True)
# Epoch 209: Parameter containing:
# tensor([3.1379, 7.2581], requires_grad=True)
# Epoch 210: Parameter containing:
# tensor([3.1345, 7.2813], requires_grad=True)
# Epoch 211: Parameter containing:
# tensor([3.1311, 7.3044], requires_grad=True)
# Epoch 212: Parameter containing:
# tensor([3.1277, 7.3276], requires_grad=True)
# Epoch 213: Parameter containing:
# tensor([3.1243, 7.3507], requires_grad=True)
# Epoch 214: Parameter containing:
# tensor([3.1209, 7.3739], requires_grad=True)
# Epoch 215: Parameter containing:
# tensor([3.1175, 7.3970], requires_grad=True)
# Epoch 216: Parameter containing:
# tensor([3.1141, 7.4201], requires_grad=True)
# Epoch 217: Parameter containing:
# tensor([3.1107, 7.4432], requires_grad=True)
# Epoch 218: Parameter containing:
# tensor([3.1073, 7.4663], requires_grad=True)
# Epoch 219: Parameter containing:
# tensor([3.1039, 7.4893], requires_grad=True)
# Epoch 220: Parameter containing:
# tensor([3.1005, 7.5124], requires_grad=True)
# Epoch 221: Parameter containing:
# tensor([3.0971, 7.5354], requires_grad=True)
# Epoch 222: Parameter containing:
# tensor([3.0937, 7.5584], requires_grad=True)
# Epoch 223: Parameter containing:
# tensor([3.0903, 7.5814], requires_grad=True)
# Epoch 224: Parameter containing:
# tensor([3.0869, 7.6044], requires_grad=True)
# Epoch 225: Parameter containing:
# tensor([3.0836, 7.6274], requires_grad=True)
# Epoch 226: Parameter containing:
# tensor([3.0802, 7.6504], requires_grad=True)
# Epoch 227: Parameter containing:
# tensor([3.0768, 7.6733], requires_grad=True)
# Epoch 228: Parameter containing:
# tensor([3.0734, 7.6963], requires_grad=True)
# Epoch 229: Parameter containing:
# tensor([3.0700, 7.7192], requires_grad=True)
# Epoch 230: Parameter containing:
# tensor([3.0667, 7.7421], requires_grad=True)
# Epoch 231: Parameter containing:
# tensor([3.0633, 7.7650], requires_grad=True)
# Epoch 232: Parameter containing:
# tensor([3.0599, 7.7878], requires_grad=True)
# Epoch 233: Parameter containing:
# tensor([3.0566, 7.8107], requires_grad=True)
# Epoch 234: Parameter containing:
# tensor([3.0532, 7.8335], requires_grad=True)
# Epoch 235: Parameter containing:
# tensor([3.0498, 7.8563], requires_grad=True)
# Epoch 236: Parameter containing:
# tensor([3.0465, 7.8791], requires_grad=True)
# Epoch 237: Parameter containing:
# tensor([3.0431, 7.9018], requires_grad=True)
# Epoch 238: Parameter containing:
# tensor([3.0398, 7.9246], requires_grad=True)
# Epoch 239: Parameter containing:
# tensor([3.0365, 7.9473], requires_grad=True)
# Epoch 240: Parameter containing:
# tensor([3.0331, 7.9700], requires_grad=True)
# Epoch 241: Parameter containing:
# tensor([3.0298, 7.9927], requires_grad=True)
# Epoch 242: Parameter containing:
# tensor([3.0264, 8.0154], requires_grad=True)
# Epoch 243: Parameter containing:
# tensor([3.0231, 8.0380], requires_grad=True)
# Epoch 244: Parameter containing:
# tensor([3.0198, 8.0606], requires_grad=True)
# Epoch 245: Parameter containing:
# tensor([3.0165, 8.0832], requires_grad=True)
# Epoch 246: Parameter containing:
# tensor([3.0131, 8.1058], requires_grad=True)
# Epoch 247: Parameter containing:
# tensor([3.0098, 8.1284], requires_grad=True)
# Epoch 248: Parameter containing:
# tensor([3.0065, 8.1509], requires_grad=True)
# Epoch 249: Parameter containing:
# tensor([3.0032, 8.1734], requires_grad=True)
# Epoch 250: Parameter containing:
# tensor([2.9999, 8.1959], requires_grad=True)
# Epoch 251: Parameter containing:
# tensor([2.9966, 8.2184], requires_grad=True)
# Epoch 252: Parameter containing:
# tensor([2.9933, 8.2408], requires_grad=True)
# Epoch 253: Parameter containing:
# tensor([2.9900, 8.2632], requires_grad=True)
# Epoch 254: Parameter containing:
# tensor([2.9867, 8.2856], requires_grad=True)
# Epoch 255: Parameter containing:
# tensor([2.9834, 8.3079], requires_grad=True)
# Epoch 256: Parameter containing:
# tensor([2.9801, 8.3303], requires_grad=True)
# Epoch 257: Parameter containing:
# tensor([2.9768, 8.3526], requires_grad=True)
# Epoch 258: Parameter containing:
# tensor([2.9736, 8.3749], requires_grad=True)
# Epoch 259: Parameter containing:
# tensor([2.9703, 8.3971], requires_grad=True)
# Epoch 260: Parameter containing:
# tensor([2.9670, 8.4194], requires_grad=True)
# Epoch 261: Parameter containing:
# tensor([2.9638, 8.4416], requires_grad=True)
# Epoch 262: Parameter containing:
# tensor([2.9605, 8.4637], requires_grad=True)
# Epoch 263: Parameter containing:
# tensor([2.9572, 8.4859], requires_grad=True)
# Epoch 264: Parameter containing:
# tensor([2.9540, 8.5080], requires_grad=True)
# Epoch 265: Parameter containing:
# tensor([2.9507, 8.5301], requires_grad=True)
# Epoch 266: Parameter containing:
# tensor([2.9475, 8.5522], requires_grad=True)
# Epoch 267: Parameter containing:
# tensor([2.9443, 8.5742], requires_grad=True)
# Epoch 268: Parameter containing:
# tensor([2.9410, 8.5962], requires_grad=True)
# Epoch 269: Parameter containing:
# tensor([2.9378, 8.6182], requires_grad=True)
# Epoch 270: Parameter containing:
# tensor([2.9346, 8.6401], requires_grad=True)
# Epoch 271: Parameter containing:
# tensor([2.9313, 8.6620], requires_grad=True)
# Epoch 272: Parameter containing:
# tensor([2.9281, 8.6839], requires_grad=True)
# Epoch 273: Parameter containing:
# tensor([2.9249, 8.7058], requires_grad=True)
# Epoch 274: Parameter containing:
# tensor([2.9217, 8.7276], requires_grad=True)
# Epoch 275: Parameter containing:
# tensor([2.9185, 8.7494], requires_grad=True)
# Epoch 276: Parameter containing:
# tensor([2.9153, 8.7711], requires_grad=True)
# Epoch 277: Parameter containing:
# tensor([2.9121, 8.7929], requires_grad=True)
# Epoch 278: Parameter containing:
# tensor([2.9089, 8.8146], requires_grad=True)
# Epoch 279: Parameter containing:
# tensor([2.9057, 8.8362], requires_grad=True)
# Epoch 280: Parameter containing:
# tensor([2.9025, 8.8579], requires_grad=True)
# Epoch 281: Parameter containing:
# tensor([2.8994, 8.8795], requires_grad=True)
# Epoch 282: Parameter containing:
# tensor([2.8962, 8.9011], requires_grad=True)
# Epoch 283: Parameter containing:
# tensor([2.8930, 8.9226], requires_grad=True)
# Epoch 284: Parameter containing:
# tensor([2.8899, 8.9441], requires_grad=True)
# Epoch 285: Parameter containing:
# tensor([2.8867, 8.9656], requires_grad=True)
# Epoch 286: Parameter containing:
# tensor([2.8836, 8.9870], requires_grad=True)
# Epoch 287: Parameter containing:
# tensor([2.8804, 9.0084], requires_grad=True)
# Epoch 288: Parameter containing:
# tensor([2.8773, 9.0298], requires_grad=True)
# Epoch 289: Parameter containing:
# tensor([2.8741, 9.0511], requires_grad=True)
# Epoch 290: Parameter containing:
# tensor([2.8710, 9.0724], requires_grad=True)
# Epoch 291: Parameter containing:
# tensor([2.8679, 9.0937], requires_grad=True)
# Epoch 292: Parameter containing:
# tensor([2.8648, 9.1149], requires_grad=True)
# Epoch 293: Parameter containing:
# tensor([2.8616, 9.1361], requires_grad=True)
# Epoch 294: Parameter containing:
# tensor([2.8585, 9.1573], requires_grad=True)
# Epoch 295: Parameter containing:
# tensor([2.8554, 9.1784], requires_grad=True)
# Epoch 296: Parameter containing:
# tensor([2.8523, 9.1995], requires_grad=True)
# Epoch 297: Parameter containing:
# tensor([2.8492, 9.2206], requires_grad=True)
# Epoch 298: Parameter containing:
# tensor([2.8461, 9.2416], requires_grad=True)
# Epoch 299: Parameter containing:
# tensor([2.8430, 9.2626], requires_grad=True)
# Epoch 300: Parameter containing:
# tensor([2.8400, 9.2835], requires_grad=True)
# Epoch 301: Parameter containing:
# tensor([2.8369, 9.3045], requires_grad=True)
# Epoch 302: Parameter containing:
# tensor([2.8338, 9.3253], requires_grad=True)
# Epoch 303: Parameter containing:
# tensor([2.8308, 9.3462], requires_grad=True)
# Epoch 304: Parameter containing:
# tensor([2.8277, 9.3670], requires_grad=True)
# Epoch 305: Parameter containing:
# tensor([2.8246, 9.3877], requires_grad=True)
# Epoch 306: Parameter containing:
# tensor([2.8216, 9.4085], requires_grad=True)
# Epoch 307: Parameter containing:
# tensor([2.8186, 9.4292], requires_grad=True)
# Epoch 308: Parameter containing:
# tensor([2.8155, 9.4498], requires_grad=True)
# Epoch 309: Parameter containing:
# tensor([2.8125, 9.4704], requires_grad=True)
# Epoch 310: Parameter containing:
# tensor([2.8095, 9.4910], requires_grad=True)
# Epoch 311: Parameter containing:
# tensor([2.8064, 9.5116], requires_grad=True)
# Epoch 312: Parameter containing:
# tensor([2.8034, 9.5321], requires_grad=True)
# Epoch 313: Parameter containing:
# tensor([2.8004, 9.5525], requires_grad=True)
# Epoch 314: Parameter containing:
# tensor([2.7974, 9.5729], requires_grad=True)
# Epoch 315: Parameter containing:
# tensor([2.7944, 9.5933], requires_grad=True)
# Epoch 316: Parameter containing:
# tensor([2.7914, 9.6137], requires_grad=True)
# Epoch 317: Parameter containing:
# tensor([2.7884, 9.6340], requires_grad=True)
# Epoch 318: Parameter containing:
# tensor([2.7855, 9.6542], requires_grad=True)
# Epoch 319: Parameter containing:
# tensor([2.7825, 9.6745], requires_grad=True)
# Epoch 320: Parameter containing:
# tensor([2.7795, 9.6947], requires_grad=True)
# Epoch 321: Parameter containing:
# tensor([2.7766, 9.7148], requires_grad=True)
# Epoch 322: Parameter containing:
# tensor([2.7736, 9.7349], requires_grad=True)
# Epoch 323: Parameter containing:
# tensor([2.7707, 9.7550], requires_grad=True)
# Epoch 324: Parameter containing:
# tensor([2.7677, 9.7750], requires_grad=True)
# Epoch 325: Parameter containing:
# tensor([2.7648, 9.7950], requires_grad=True)
# Epoch 326: Parameter containing:
# tensor([2.7618, 9.8149], requires_grad=True)
# Epoch 327: Parameter containing:
# tensor([2.7589, 9.8349], requires_grad=True)
# Epoch 328: Parameter containing:
# tensor([2.7560, 9.8547], requires_grad=True)
# Epoch 329: Parameter containing:
# tensor([2.7531, 9.8745], requires_grad=True)
# Epoch 330: Parameter containing:
# tensor([2.7502, 9.8943], requires_grad=True)
# Epoch 331: Parameter containing:
# tensor([2.7473, 9.9141], requires_grad=True)
# Epoch 332: Parameter containing:
# tensor([2.7444, 9.9338], requires_grad=True)
# Epoch 333: Parameter containing:
# tensor([2.7415, 9.9534], requires_grad=True)
# Epoch 334: Parameter containing:
# tensor([2.7386, 9.9730], requires_grad=True)
# Epoch 335: Parameter containing:
# tensor([2.7357, 9.9926], requires_grad=True)
# Epoch 336: Parameter containing:
# tensor([ 2.7329, 10.0122], requires_grad=True)
# Epoch 337: Parameter containing:
# tensor([ 2.7300, 10.0316], requires_grad=True)
# Epoch 338: Parameter containing:
# tensor([ 2.7271, 10.0511], requires_grad=True)
# Epoch 339: Parameter containing:
# tensor([ 2.7243, 10.0705], requires_grad=True)
# Epoch 340: Parameter containing:
# tensor([ 2.7214, 10.0899], requires_grad=True)
# Epoch 341: Parameter containing:
# tensor([ 2.7186, 10.1092], requires_grad=True)
# Epoch 342: Parameter containing:
# tensor([ 2.7158, 10.1285], requires_grad=True)
# Epoch 343: Parameter containing:
# tensor([ 2.7129, 10.1477], requires_grad=True)
# Epoch 344: Parameter containing:
# tensor([ 2.7101, 10.1669], requires_grad=True)
# Epoch 345: Parameter containing:
# tensor([ 2.7073, 10.1861], requires_grad=True)
# Epoch 346: Parameter containing:
# tensor([ 2.7045, 10.2052], requires_grad=True)
# Epoch 347: Parameter containing:
# tensor([ 2.7017, 10.2242], requires_grad=True)
# Epoch 348: Parameter containing:
# tensor([ 2.6989, 10.2432], requires_grad=True)
# Epoch 349: Parameter containing:
# tensor([ 2.6961, 10.2622], requires_grad=True)
# Epoch 350: Parameter containing:
# tensor([ 2.6933, 10.2812], requires_grad=True)
# Epoch 351: Parameter containing:
# tensor([ 2.6905, 10.3001], requires_grad=True)
# Epoch 352: Parameter containing:
# tensor([ 2.6878, 10.3189], requires_grad=True)
# Epoch 353: Parameter containing:
# tensor([ 2.6850, 10.3377], requires_grad=True)
# Epoch 354: Parameter containing:
# tensor([ 2.6823, 10.3565], requires_grad=True)
# Epoch 355: Parameter containing:
# tensor([ 2.6795, 10.3752], requires_grad=True)
# Epoch 356: Parameter containing:
# tensor([ 2.6768, 10.3939], requires_grad=True)
# Epoch 357: Parameter containing:
# tensor([ 2.6740, 10.4125], requires_grad=True)
# Epoch 358: Parameter containing:
# tensor([ 2.6713, 10.4311], requires_grad=True)
# Epoch 359: Parameter containing:
# tensor([ 2.6686, 10.4496], requires_grad=True)
# Epoch 360: Parameter containing:
# tensor([ 2.6658, 10.4681], requires_grad=True)
# Epoch 361: Parameter containing:
# tensor([ 2.6631, 10.4866], requires_grad=True)
# Epoch 362: Parameter containing:
# tensor([ 2.6604, 10.5050], requires_grad=True)
# Epoch 363: Parameter containing:
# tensor([ 2.6577, 10.5233], requires_grad=True)
# Epoch 364: Parameter containing:
# tensor([ 2.6550, 10.5416], requires_grad=True)
# Epoch 365: Parameter containing:
# tensor([ 2.6524, 10.5599], requires_grad=True)
# Epoch 366: Parameter containing:
# tensor([ 2.6497, 10.5781], requires_grad=True)
# Epoch 367: Parameter containing:
# tensor([ 2.6470, 10.5963], requires_grad=True)
# Epoch 368: Parameter containing:
# tensor([ 2.6443, 10.6145], requires_grad=True)
# Epoch 369: Parameter containing:
# tensor([ 2.6417, 10.6326], requires_grad=True)
# Epoch 370: Parameter containing:
# tensor([ 2.6390, 10.6506], requires_grad=True)
# Epoch 371: Parameter containing:
# tensor([ 2.6364, 10.6686], requires_grad=True)
# Epoch 372: Parameter containing:
# tensor([ 2.6337, 10.6866], requires_grad=True)
# Epoch 373: Parameter containing:
# tensor([ 2.6311, 10.7045], requires_grad=True)
# Epoch 374: Parameter containing:
# tensor([ 2.6285, 10.7223], requires_grad=True)
# Epoch 375: Parameter containing:
# tensor([ 2.6259, 10.7402], requires_grad=True)
# Epoch 376: Parameter containing:
# tensor([ 2.6232, 10.7579], requires_grad=True)
# Epoch 377: Parameter containing:
# tensor([ 2.6206, 10.7757], requires_grad=True)
# Epoch 378: Parameter containing:
# tensor([ 2.6180, 10.7933], requires_grad=True)
# Epoch 379: Parameter containing:
# tensor([ 2.6155, 10.8110], requires_grad=True)
# Epoch 380: Parameter containing:
# tensor([ 2.6129, 10.8286], requires_grad=True)
# Epoch 381: Parameter containing:
# tensor([ 2.6103, 10.8461], requires_grad=True)
# Epoch 382: Parameter containing:
# tensor([ 2.6077, 10.8636], requires_grad=True)
# Epoch 383: Parameter containing:
# tensor([ 2.6052, 10.8811], requires_grad=True)
# Epoch 384: Parameter containing:
# tensor([ 2.6026, 10.8985], requires_grad=True)
# Epoch 385: Parameter containing:
# tensor([ 2.6000, 10.9158], requires_grad=True)
# Epoch 386: Parameter containing:
# tensor([ 2.5975, 10.9332], requires_grad=True)
# Epoch 387: Parameter containing:
# tensor([ 2.5950, 10.9504], requires_grad=True)
# Epoch 388: Parameter containing:
# tensor([ 2.5924, 10.9677], requires_grad=True)
# Epoch 389: Parameter containing:
# tensor([ 2.5899, 10.9848], requires_grad=True)
# Epoch 390: Parameter containing:
# tensor([ 2.5874, 11.0020], requires_grad=True)
# Epoch 391: Parameter containing:
# tensor([ 2.5849, 11.0191], requires_grad=True)
# Epoch 392: Parameter containing:
# tensor([ 2.5824, 11.0361], requires_grad=True)
# Epoch 393: Parameter containing:
# tensor([ 2.5799, 11.0531], requires_grad=True)
# Epoch 394: Parameter containing:
# tensor([ 2.5774, 11.0700], requires_grad=True)
# Epoch 395: Parameter containing:
# tensor([ 2.5749, 11.0869], requires_grad=True)
# Epoch 396: Parameter containing:
# tensor([ 2.5724, 11.1038], requires_grad=True)
# Epoch 397: Parameter containing:
# tensor([ 2.5700, 11.1206], requires_grad=True)
# Epoch 398: Parameter containing:
# tensor([ 2.5675, 11.1373], requires_grad=True)
# Epoch 399: Parameter containing:
# tensor([ 2.5650, 11.1541], requires_grad=True)
# Epoch 400: Parameter containing:
# tensor([ 2.5626, 11.1707], requires_grad=True)
# Epoch 401: Parameter containing:
# tensor([ 2.5601, 11.1874], requires_grad=True)
# Epoch 402: Parameter containing:
# tensor([ 2.5577, 11.2039], requires_grad=True)
# Epoch 403: Parameter containing:
# tensor([ 2.5553, 11.2205], requires_grad=True)
# Epoch 404: Parameter containing:
# tensor([ 2.5529, 11.2369], requires_grad=True)
# Epoch 405: Parameter containing:
# tensor([ 2.5504, 11.2534], requires_grad=True)
# Epoch 406: Parameter containing:
# tensor([ 2.5480, 11.2698], requires_grad=True)
# Epoch 407: Parameter containing:
# tensor([ 2.5456, 11.2861], requires_grad=True)
# Epoch 408: Parameter containing:
# tensor([ 2.5432, 11.3024], requires_grad=True)
# Epoch 409: Parameter containing:
# tensor([ 2.5409, 11.3186], requires_grad=True)
# Epoch 410: Parameter containing:
# tensor([ 2.5385, 11.3348], requires_grad=True)
# Epoch 411: Parameter containing:
# tensor([ 2.5361, 11.3510], requires_grad=True)
# Epoch 412: Parameter containing:
# tensor([ 2.5337, 11.3671], requires_grad=True)
# Epoch 413: Parameter containing:
# tensor([ 2.5314, 11.3832], requires_grad=True)
# Epoch 414: Parameter containing:
# tensor([ 2.5290, 11.3992], requires_grad=True)
# Epoch 415: Parameter containing:
# tensor([ 2.5267, 11.4151], requires_grad=True)
# Epoch 416: Parameter containing:
# tensor([ 2.5243, 11.4310], requires_grad=True)
# Epoch 417: Parameter containing:
# tensor([ 2.5220, 11.4469], requires_grad=True)
# Epoch 418: Parameter containing:
# tensor([ 2.5197, 11.4627], requires_grad=True)
# Epoch 419: Parameter containing:
# tensor([ 2.5174, 11.4785], requires_grad=True)
# Epoch 420: Parameter containing:
# tensor([ 2.5150, 11.4943], requires_grad=True)
# Epoch 421: Parameter containing:
# tensor([ 2.5127, 11.5099], requires_grad=True)
# Epoch 422: Parameter containing:
# tensor([ 2.5104, 11.5256], requires_grad=True)
# Epoch 423: Parameter containing:
# tensor([ 2.5082, 11.5412], requires_grad=True)
# Epoch 424: Parameter containing:
# tensor([ 2.5059, 11.5567], requires_grad=True)
# Epoch 425: Parameter containing:
# tensor([ 2.5036, 11.5722], requires_grad=True)
# Epoch 426: Parameter containing:
# tensor([ 2.5013, 11.5876], requires_grad=True)
# Epoch 427: Parameter containing:
# tensor([ 2.4991, 11.6031], requires_grad=True)
# Epoch 428: Parameter containing:
# tensor([ 2.4968, 11.6184], requires_grad=True)
# Epoch 429: Parameter containing:
# tensor([ 2.4946, 11.6337], requires_grad=True)
# Epoch 430: Parameter containing:
# tensor([ 2.4923, 11.6490], requires_grad=True)
# Epoch 431: Parameter containing:
# tensor([ 2.4901, 11.6642], requires_grad=True)
# Epoch 432: Parameter containing:
# tensor([ 2.4878, 11.6794], requires_grad=True)
# Epoch 433: Parameter containing:
# tensor([ 2.4856, 11.6945], requires_grad=True)
# Epoch 434: Parameter containing:
# tensor([ 2.4834, 11.7095], requires_grad=True)
# Epoch 435: Parameter containing:
# tensor([ 2.4812, 11.7246], requires_grad=True)
# Epoch 436: Parameter containing:
# tensor([ 2.4790, 11.7396], requires_grad=True)
# Epoch 437: Parameter containing:
# tensor([ 2.4768, 11.7545], requires_grad=True)
# Epoch 438: Parameter containing:
# tensor([ 2.4746, 11.7694], requires_grad=True)
# Epoch 439: Parameter containing:
# tensor([ 2.4724, 11.7842], requires_grad=True)
# Epoch 440: Parameter containing:
# tensor([ 2.4703, 11.7990], requires_grad=True)
# Epoch 441: Parameter containing:
# tensor([ 2.4681, 11.8137], requires_grad=True)
# Epoch 442: Parameter containing:
# tensor([ 2.4659, 11.8284], requires_grad=True)
# Epoch 443: Parameter containing:
# tensor([ 2.4638, 11.8431], requires_grad=True)
# Epoch 444: Parameter containing:
# tensor([ 2.4616, 11.8577], requires_grad=True)
# Epoch 445: Parameter containing:
# tensor([ 2.4595, 11.8723], requires_grad=True)
# Epoch 446: Parameter containing:
# tensor([ 2.4574, 11.8868], requires_grad=True)
# Epoch 447: Parameter containing:
# tensor([ 2.4552, 11.9012], requires_grad=True)
# Epoch 448: Parameter containing:
# tensor([ 2.4531, 11.9157], requires_grad=True)
# Epoch 449: Parameter containing:
# tensor([ 2.4510, 11.9300], requires_grad=True)
# Epoch 450: Parameter containing:
# tensor([ 2.4489, 11.9443], requires_grad=True)
# Epoch 451: Parameter containing:
# tensor([ 2.4468, 11.9586], requires_grad=True)
# Epoch 452: Parameter containing:
# tensor([ 2.4447, 11.9729], requires_grad=True)
# Epoch 453: Parameter containing:
# tensor([ 2.4426, 11.9870], requires_grad=True)
# Epoch 454: Parameter containing:
# tensor([ 2.4406, 12.0012], requires_grad=True)
# Epoch 455: Parameter containing:
# tensor([ 2.4385, 12.0153], requires_grad=True)
# Epoch 456: Parameter containing:
# tensor([ 2.4364, 12.0293], requires_grad=True)
# Epoch 457: Parameter containing:
# tensor([ 2.4344, 12.0433], requires_grad=True)
# Epoch 458: Parameter containing:
# tensor([ 2.4323, 12.0573], requires_grad=True)
# Epoch 459: Parameter containing:
# tensor([ 2.4303, 12.0712], requires_grad=True)
# Epoch 460: Parameter containing:
# tensor([ 2.4282, 12.0850], requires_grad=True)
# Epoch 461: Parameter containing:
# tensor([ 2.4262, 12.0988], requires_grad=True)
# Epoch 462: Parameter containing:
# tensor([ 2.4242, 12.1126], requires_grad=True)
# Epoch 463: Parameter containing:
# tensor([ 2.4222, 12.1263], requires_grad=True)
# Epoch 464: Parameter containing:
# tensor([ 2.4202, 12.1400], requires_grad=True)
# Epoch 465: Parameter containing:
# tensor([ 2.4182, 12.1536], requires_grad=True)
# Epoch 466: Parameter containing:
# tensor([ 2.4162, 12.1672], requires_grad=True)
# Epoch 467: Parameter containing:
# tensor([ 2.4142, 12.1808], requires_grad=True)
# Epoch 468: Parameter containing:
# tensor([ 2.4122, 12.1942], requires_grad=True)
# Epoch 469: Parameter containing:
# tensor([ 2.4102, 12.2077], requires_grad=True)
# Epoch 470: Parameter containing:
# tensor([ 2.4083, 12.2211], requires_grad=True)
# Epoch 471: Parameter containing:
# tensor([ 2.4063, 12.2344], requires_grad=True)
# Epoch 472: Parameter containing:
# tensor([ 2.4043, 12.2477], requires_grad=True)
# Epoch 473: Parameter containing:
# tensor([ 2.4024, 12.2610], requires_grad=True)
# Epoch 474: Parameter containing:
# tensor([ 2.4004, 12.2742], requires_grad=True)
# Epoch 475: Parameter containing:
# tensor([ 2.3985, 12.2874], requires_grad=True)
# Epoch 476: Parameter containing:
# tensor([ 2.3966, 12.3005], requires_grad=True)
# Epoch 477: Parameter containing:
# tensor([ 2.3947, 12.3136], requires_grad=True)
# Epoch 478: Parameter containing:
# tensor([ 2.3927, 12.3266], requires_grad=True)
# Epoch 479: Parameter containing:
# tensor([ 2.3908, 12.3396], requires_grad=True)
# Epoch 480: Parameter containing:
# tensor([ 2.3889, 12.3525], requires_grad=True)
# Epoch 481: Parameter containing:
# tensor([ 2.3870, 12.3654], requires_grad=True)
# Epoch 482: Parameter containing:
# tensor([ 2.3852, 12.3783], requires_grad=True)
# Epoch 483: Parameter containing:
# tensor([ 2.3833, 12.3911], requires_grad=True)
# Epoch 484: Parameter containing:
# tensor([ 2.3814, 12.4038], requires_grad=True)
# Epoch 485: Parameter containing:
# tensor([ 2.3795, 12.4166], requires_grad=True)
# Epoch 486: Parameter containing:
# tensor([ 2.3777, 12.4292], requires_grad=True)
# Epoch 487: Parameter containing:
# tensor([ 2.3758, 12.4418], requires_grad=True)
# Epoch 488: Parameter containing:
# tensor([ 2.3740, 12.4544], requires_grad=True)
# Epoch 489: Parameter containing:
# tensor([ 2.3721, 12.4670], requires_grad=True)
# Epoch 490: Parameter containing:
# tensor([ 2.3703, 12.4794], requires_grad=True)
# Epoch 491: Parameter containing:
# tensor([ 2.3685, 12.4919], requires_grad=True)
# Epoch 492: Parameter containing:
# tensor([ 2.3666, 12.5043], requires_grad=True)
# Epoch 493: Parameter containing:
# tensor([ 2.3648, 12.5166], requires_grad=True)
# Epoch 494: Parameter containing:
# tensor([ 2.3630, 12.5289], requires_grad=True)
# Epoch 495: Parameter containing:
# tensor([ 2.3612, 12.5412], requires_grad=True)
# Epoch 496: Parameter containing:
# tensor([ 2.3594, 12.5534], requires_grad=True)
# Epoch 497: Parameter containing:
# tensor([ 2.3576, 12.5656], requires_grad=True)
# Epoch 498: Parameter containing:
# tensor([ 2.3559, 12.5777], requires_grad=True)
# Epoch 499: Parameter containing:
# tensor([ 2.3541, 12.5898], requires_grad=True)
# Epoch 500: Parameter containing:
# tensor([ 2.3523, 12.6019], requires_grad=True)
# Epoch 501: Parameter containing:
# tensor([ 2.3505, 12.6139], requires_grad=True)
# Epoch 502: Parameter containing:
# tensor([ 2.3488, 12.6258], requires_grad=True)
# Epoch 503: Parameter containing:
# tensor([ 2.3470, 12.6377], requires_grad=True)
# Epoch 504: Parameter containing:
# tensor([ 2.3453, 12.6496], requires_grad=True)
# Epoch 505: Parameter containing:
# tensor([ 2.3436, 12.6614], requires_grad=True)
# Epoch 506: Parameter containing:
# tensor([ 2.3418, 12.6732], requires_grad=True)
# Epoch 507: Parameter containing:
# tensor([ 2.3401, 12.6849], requires_grad=True)
# Epoch 508: Parameter containing:
# tensor([ 2.3384, 12.6966], requires_grad=True)
# Epoch 509: Parameter containing:
# tensor([ 2.3367, 12.7082], requires_grad=True)
# Epoch 510: Parameter containing:
# tensor([ 2.3350, 12.7198], requires_grad=True)
# Epoch 511: Parameter containing:
# tensor([ 2.3333, 12.7314], requires_grad=True)
# Epoch 512: Parameter containing:
# tensor([ 2.3316, 12.7429], requires_grad=True)
# Epoch 513: Parameter containing:
# tensor([ 2.3299, 12.7544], requires_grad=True)
# Epoch 514: Parameter containing:
# tensor([ 2.3282, 12.7658], requires_grad=True)
# Epoch 515: Parameter containing:
# tensor([ 2.3265, 12.7772], requires_grad=True)
# Epoch 516: Parameter containing:
# tensor([ 2.3249, 12.7885], requires_grad=True)
# Epoch 517: Parameter containing:
# tensor([ 2.3232, 12.7998], requires_grad=True)
# Epoch 518: Parameter containing:
# tensor([ 2.3216, 12.8111], requires_grad=True)
# Epoch 519: Parameter containing:
# tensor([ 2.3199, 12.8223], requires_grad=True)
# Epoch 520: Parameter containing:
# tensor([ 2.3183, 12.8334], requires_grad=True)
# Epoch 521: Parameter containing:
# tensor([ 2.3167, 12.8446], requires_grad=True)
# Epoch 522: Parameter containing:
# tensor([ 2.3150, 12.8556], requires_grad=True)
# Epoch 523: Parameter containing:
# tensor([ 2.3134, 12.8667], requires_grad=True)
# Epoch 524: Parameter containing:
# tensor([ 2.3118, 12.8777], requires_grad=True)
# Epoch 525: Parameter containing:
# tensor([ 2.3102, 12.8886], requires_grad=True)
# Epoch 526: Parameter containing:
# tensor([ 2.3086, 12.8995], requires_grad=True)
# Epoch 527: Parameter containing:
# tensor([ 2.3070, 12.9104], requires_grad=True)
# Epoch 528: Parameter containing:
# tensor([ 2.3054, 12.9212], requires_grad=True)
# Epoch 529: Parameter containing:
# tensor([ 2.3038, 12.9320], requires_grad=True)
# Epoch 530: Parameter containing:
# tensor([ 2.3022, 12.9427], requires_grad=True)
# Epoch 531: Parameter containing:
# tensor([ 2.3007, 12.9534], requires_grad=True)
# Epoch 532: Parameter containing:
# tensor([ 2.2991, 12.9641], requires_grad=True)
# Epoch 533: Parameter containing:
# tensor([ 2.2975, 12.9747], requires_grad=True)
# Epoch 534: Parameter containing:
# tensor([ 2.2960, 12.9853], requires_grad=True)
# Epoch 535: Parameter containing:
# tensor([ 2.2944, 12.9958], requires_grad=True)
# Epoch 536: Parameter containing:
# tensor([ 2.2929, 13.0063], requires_grad=True)
# Epoch 537: Parameter containing:
# tensor([ 2.2914, 13.0167], requires_grad=True)
# Epoch 538: Parameter containing:
# tensor([ 2.2898, 13.0271], requires_grad=True)
# Epoch 539: Parameter containing:
# tensor([ 2.2883, 13.0375], requires_grad=True)
# Epoch 540: Parameter containing:
# tensor([ 2.2868, 13.0478], requires_grad=True)
# Epoch 541: Parameter containing:
# tensor([ 2.2853, 13.0581], requires_grad=True)
# Epoch 542: Parameter containing:
# tensor([ 2.2838, 13.0683], requires_grad=True)
# Epoch 543: Parameter containing:
# tensor([ 2.2823, 13.0785], requires_grad=True)
# Epoch 544: Parameter containing:
# tensor([ 2.2808, 13.0887], requires_grad=True)
# Epoch 545: Parameter containing:
# tensor([ 2.2793, 13.0988], requires_grad=True)
# Epoch 546: Parameter containing:
# tensor([ 2.2778, 13.1089], requires_grad=True)
# Epoch 547: Parameter containing:
# tensor([ 2.2763, 13.1189], requires_grad=True)
# Epoch 548: Parameter containing:
# tensor([ 2.2749, 13.1289], requires_grad=True)
# Epoch 549: Parameter containing:
# tensor([ 2.2734, 13.1388], requires_grad=True)
# Epoch 550: Parameter containing:
# tensor([ 2.2720, 13.1487], requires_grad=True)
# Epoch 551: Parameter containing:
# tensor([ 2.2705, 13.1586], requires_grad=True)
# Epoch 552: Parameter containing:
# tensor([ 2.2691, 13.1684], requires_grad=True)
# Epoch 553: Parameter containing:
# tensor([ 2.2676, 13.1782], requires_grad=True)
# Epoch 554: Parameter containing:
# tensor([ 2.2662, 13.1880], requires_grad=True)
# Epoch 555: Parameter containing:
# tensor([ 2.2648, 13.1977], requires_grad=True)
# Epoch 556: Parameter containing:
# tensor([ 2.2634, 13.2073], requires_grad=True)
# Epoch 557: Parameter containing:
# tensor([ 2.2619, 13.2170], requires_grad=True)
# Epoch 558: Parameter containing:
# tensor([ 2.2605, 13.2266], requires_grad=True)
# Epoch 559: Parameter containing:
# tensor([ 2.2591, 13.2361], requires_grad=True)
# Epoch 560: Parameter containing:
# tensor([ 2.2577, 13.2456], requires_grad=True)
# Epoch 561: Parameter containing:
# tensor([ 2.2563, 13.2551], requires_grad=True)
# Epoch 562: Parameter containing:
# tensor([ 2.2550, 13.2645], requires_grad=True)
# Epoch 563: Parameter containing:
# tensor([ 2.2536, 13.2739], requires_grad=True)
# Epoch 564: Parameter containing:
# tensor([ 2.2522, 13.2832], requires_grad=True)
# Epoch 565: Parameter containing:
# tensor([ 2.2508, 13.2926], requires_grad=True)
# Epoch 566: Parameter containing:
# tensor([ 2.2495, 13.3018], requires_grad=True)
# Epoch 567: Parameter containing:
# tensor([ 2.2481, 13.3111], requires_grad=True)
# Epoch 568: Parameter containing:
# tensor([ 2.2468, 13.3202], requires_grad=True)
# Epoch 569: Parameter containing:
# tensor([ 2.2454, 13.3294], requires_grad=True)
# Epoch 570: Parameter containing:
# tensor([ 2.2441, 13.3385], requires_grad=True)
# Epoch 571: Parameter containing:
# tensor([ 2.2427, 13.3476], requires_grad=True)
# Epoch 572: Parameter containing:
# tensor([ 2.2414, 13.3566], requires_grad=True)
# Epoch 573: Parameter containing:
# tensor([ 2.2401, 13.3656], requires_grad=True)
# Epoch 574: Parameter containing:
# tensor([ 2.2388, 13.3746], requires_grad=True)
# Epoch 575: Parameter containing:
# tensor([ 2.2375, 13.3835], requires_grad=True)
# Epoch 576: Parameter containing:
# tensor([ 2.2362, 13.3924], requires_grad=True)
# Epoch 577: Parameter containing:
# tensor([ 2.2349, 13.4012], requires_grad=True)
# Epoch 578: Parameter containing:
# tensor([ 2.2336, 13.4100], requires_grad=True)
# Epoch 579: Parameter containing:
# tensor([ 2.2323, 13.4188], requires_grad=True)
# Epoch 580: Parameter containing:
# tensor([ 2.2310, 13.4275], requires_grad=True)
# Epoch 581: Parameter containing:
# tensor([ 2.2297, 13.4362], requires_grad=True)
# Epoch 582: Parameter containing:
# tensor([ 2.2285, 13.4449], requires_grad=True)
# Epoch 583: Parameter containing:
# tensor([ 2.2272, 13.4535], requires_grad=True)
# Epoch 584: Parameter containing:
# tensor([ 2.2259, 13.4621], requires_grad=True)
# Epoch 585: Parameter containing:
# tensor([ 2.2247, 13.4706], requires_grad=True)
# Epoch 586: Parameter containing:
# tensor([ 2.2234, 13.4791], requires_grad=True)
# Epoch 587: Parameter containing:
# tensor([ 2.2222, 13.4876], requires_grad=True)
# Epoch 588: Parameter containing:
# tensor([ 2.2209, 13.4960], requires_grad=True)
# Epoch 589: Parameter containing:
# tensor([ 2.2197, 13.5044], requires_grad=True)
# Epoch 590: Parameter containing:
# tensor([ 2.2185, 13.5128], requires_grad=True)
# Epoch 591: Parameter containing:
# tensor([ 2.2173, 13.5211], requires_grad=True)
# Epoch 592: Parameter containing:
# tensor([ 2.2160, 13.5294], requires_grad=True)
# Epoch 593: Parameter containing:
# tensor([ 2.2148, 13.5376], requires_grad=True)
# Epoch 594: Parameter containing:
# tensor([ 2.2136, 13.5458], requires_grad=True)
# Epoch 595: Parameter containing:
# tensor([ 2.2124, 13.5540], requires_grad=True)
# Epoch 596: Parameter containing:
# tensor([ 2.2112, 13.5621], requires_grad=True)
# Epoch 597: Parameter containing:
# tensor([ 2.2100, 13.5702], requires_grad=True)
# Epoch 598: Parameter containing:
# tensor([ 2.2089, 13.5783], requires_grad=True)
# Epoch 599: Parameter containing:
# tensor([ 2.2077, 13.5863], requires_grad=True)
# Epoch 600: Parameter containing:
# tensor([ 2.2065, 13.5943], requires_grad=True)
# Epoch 601: Parameter containing:
# tensor([ 2.2053, 13.6023], requires_grad=True)
# Epoch 602: Parameter containing:
# tensor([ 2.2042, 13.6102], requires_grad=True)
# Epoch 603: Parameter containing:
# tensor([ 2.2030, 13.6181], requires_grad=True)
# Epoch 604: Parameter containing:
# tensor([ 2.2019, 13.6259], requires_grad=True)
# Epoch 605: Parameter containing:
# tensor([ 2.2007, 13.6337], requires_grad=True)
# ...
# Epoch 9781: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9782: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9783: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9784: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9785: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9786: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9787: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9788: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9789: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9790: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9791: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9792: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9793: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9794: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9795: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9796: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9797: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9798: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9799: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9800: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9801: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9802: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9803: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9804: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9805: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9806: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9807: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9808: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9809: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9810: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9811: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9812: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9813: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9814: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9815: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9816: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9817: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9818: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9819: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9820: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9821: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9822: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9823: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9824: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9825: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9826: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9827: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9828: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9829: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9830: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9831: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9832: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9833: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9834: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9835: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9836: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9837: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9838: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9839: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9840: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9841: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9842: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9843: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9844: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9845: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9846: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9847: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9848: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9849: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9850: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9851: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9852: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9853: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9854: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9855: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9856: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9857: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9858: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9859: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9860: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9861: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9862: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9863: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9864: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9865: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9866: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9867: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9868: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9869: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9870: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9871: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9872: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9873: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9874: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9875: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9876: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9877: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9878: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9879: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9880: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9881: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9882: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9883: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9884: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9885: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9886: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9887: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9888: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9889: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9890: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9891: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9892: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9893: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9894: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9895: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9896: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9897: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9898: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9899: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9900: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9901: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9902: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9903: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9904: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9905: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9906: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9907: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9908: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9909: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9910: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9911: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9912: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9913: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9914: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9915: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9916: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9917: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9918: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9919: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9920: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9921: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9922: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9923: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9924: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9925: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9926: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9927: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9928: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9929: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9930: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9931: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9932: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9933: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9934: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9935: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9936: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9937: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9938: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9939: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9940: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9941: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9942: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9943: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9944: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9945: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9946: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9947: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9948: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9949: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9950: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9951: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9952: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9953: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9954: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9955: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9956: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9957: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9958: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9959: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9960: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9961: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9962: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9963: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9964: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9965: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9966: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9967: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9968: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9969: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9970: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9971: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9972: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9973: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9974: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9975: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9976: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9977: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9978: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9979: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9980: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9981: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9982: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9983: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9984: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9985: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9986: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9987: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9988: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9989: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9990: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9991: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9992: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9993: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9994: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9995: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9996: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9997: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9998: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)
# Epoch 9999: Parameter containing:
# tensor([ 2., 15.], requires_grad=True)

# %%
import numpy as np
device = th.device("cuda" if th.cuda.is_available() else "cpu")
x = [th.rand(3, dtype=th.float16) for i in range(5)]
print(x)
print(len(x[0]))
y = th.stack(x)
y.float()
y = y.to(device=device, dtype=th.float)
print(y)
print(type(y))
print(y.type())
print(y.device)
print(device)
# Out:
# [tensor([0.9868, 0.2300, 0.8413], dtype=torch.float16), tensor([0.4346, 0.3608, 0.9839], dtype=torch.float16), tensor([0.8110, 0.6636, 0.5249], dtype=torch.float16), tensor([0.1318, 0.4897, 0.2139], dtype=torch.float16), tensor([0.1748, 0.6147, 0.9346], dtype=torch.float16)]
# 3
# tensor([[0.9868, 0.2300, 0.8413],
#         [0.4346, 0.3608, 0.9839],
#         [0.8110, 0.6636, 0.5249],
#         [0.1318, 0.4897, 0.2139],
#         [0.1748, 0.6147, 0.9346]], device='cuda:0')
# <class 'torch.Tensor'>
# torch.cuda.FloatTensor
# cuda:0
# cuda
